# %%
map = ['................#......#...........#...........................#......#...........#........................................#......','.......................................................................................#........#............#.............#.....#','#.......................#...#..........#...........#........#.......................#............#................................','.............#...............................................#........#................................#....#......#..............','...#..................................#......................#....#....................................#.................#........','...................#.....#......#...........#............................#......................#.#........................#......','...........................#..#...........#.............................#.........#.##.............#..............................','.#.................#................#..........##.........##..............#...................................................#...','...............................#......................#........#.......................#.........#...........#....................','...................................#................#.............................................................................','..#...............##.......#................#.#......#...........#................................................................','....#.#.....#..............#........##........................##...........................................#...............#......','.....................#..........#.................................#.....................................#.........................','..............#.........................................##......#.......................#..............#.................#..#.....','...........#...#..........................................................#.......#.............................#................#','................................#.#...............#...............................#..............##...............................','.........................................................#............#......................................#.................#..','......#.#....#.................................#....###..................#......#.........#....#..................................','..............#...................................#..........#............#.......#...............................................','..............#......#...............#.............................................#.............................................#','....#.#..............#................#......................................................................#....................','........................................................#...........#..#.#.....................#....#.....#........#...#.......#..','..............#.......#................#............................#..#.......#.........#...........#...#...#....#....#.....#....','...#...............................................................................................#..#..#..........#.............','.......#.........#..###..................................##...............##..#.......................#..........#...........#...#','.......#.....................#.............#...........#...............................................#.................#........','..........#............................#..............................#......#..#.........#...............................#.......','.............................#...............#............#..............................................................#........','...........#...................#......#......................#.......................#...............#......#.....................','..#..............................................#.........................#.............#...#.#..................................','................#.............................#....................................#.....#...................#..#.....#...........','#............................#...#........................#................#....#.............................................#...','...............#.............#........#...................................................................#.......#....#..#.......','...........#......#.....#........................#.#..........................................#............#......................','.#.....................................................#...............#.........................#................#...........#...','.........................................#.............#......#.#....................................................#.........#..','................................#...#......................................................#..........................#..........#','.#.........................#..............#.#.....................................................................................','.........#..........#.............##.........#..#.................#........................#.....#.##....................#........','...................................................................................#...........................................#..','................#..........................................#...#...#.................................................#.........#..','..............................................#..............#..................#......#...#....#..#..............................','......#......#.................#.............#..................#...............#.............#..................#...............#','.................................#.......#......#.......#.............................................................#........#..','..................#......#...................................#.................#.......#..........................................','....................#.........#.........................#..........#..........#..................#................................','..........#...........#...............#.#..................................................................................#......','..................#..#....................................................#..........#......#................................#....','............#.................................................................................................#........#..........','.........#...............................................#.........##...........................#.................................','...#.........#........................................................#....................................#......................','........#......................#......#............#........#...............#.......................#.............................','.......#..............................................................................................#....................#......','.#.#..........#.......#.............##......................#..........................................................#..........','............#.#...........#............................................................#..........................................','............#..........................................................................#....................#...............#.....','.......................#.....#...#........................................#.......#.........#.........................#...........','....................#..............#......#.......................................................................................','......................#....................................................................#...............#...#............#.....','........#..........#....................#...#........#......#..........................#....#..................#..#...............','................#...........................................................................................................#.....','.#...............#..........................................................................................#......#..#.#.........','..............#................#...............#.........#.........#................................#.#...........................','...#................#..............#........................#...#.......................................#.#.......................','#.........................................#..#....................................................................#...............','.............#...........#.......#.#.....................................................................#.....#..................','.............#..............................................................................#.....................................','........................#........#....#........#.#.............................................^..........#.......................','...............................#.......................................................#.............##.......#.......#...........','#.#..............#..........................................#.......#..........................................#..................','...##...............................#........#.............##..................................................#..................','..#..#.................................................................#............#...#...#.....................................','....................#.#...#............#.......#.............#.......#..............#.............................................','..#..#.........#.............................................................................#......................#...#.........','....................................................#.........................#..#...#.#.#......#...............................#.','......#.....#.....................................................................#..............................................#','....................#........#..........................................................#.......#........................#........','................#.........................#...........................#...........................................#..............#','..#.......#..................................................#..................................#.................................','..........#.....................#...#.#...........#....................................#..........................................','.....................................#...........................................................#..........#...................#.','....#............................#.........................................#.........................#............................','......#............#...........#......#.#..................................#......................................................','..................#.......#.....#......#.................................................................#................#.......','...........#.....#........................................................#.............#.........................................','.................................#...........................#........#.........#............#.............................#.....#','..#........................#.................................#....................................................................','......................................................................................................#........#.#...#............','#............................#..........#.#.....................#.............................................................#...','.......#.......#................#..........#..........................#........#....#...#........................................#','....#.....#..........................................................#.........................#....................#..#.......#..','.......#.............#.................................#...................................................................#......','...............#.......................................#.#...............................#.#..........#...........................','....#......#...#.#.........................#...............#...........#.......#........................................#..#......','...................#.........................................#.....................................................#..#.....#...#.','....#......#.#.............................#..........##........#......................#.#.......................#....#...........','........#.........................#........#.#..........................##..............#....#....................................','.............#.....#..........#.....#.......#..##...#.....................#..................................#....................','....#....#...........................#...........#....................#.....#.......#....#.........#.....#....#...................','............#...#....................#..........#.......#......#............#.........................#............##.............','.....................#.................................................................####.......................................','...#...........................................................................#......#..............#....#.......#...............','....#...#...#.....................#.............#..............................#...................#...........#..................','............................#...........#........#.............#..................................................................','...#.....#......#.....................#...........................................#...........#........#..........................','.................#...........................#................................................................#..........#........','.....................#........#...#...................................................................................#......#....','.#...............................#...#....#.................#...#......#..........................................................','....................#..........#.........................................#....................#.........#.........................','.......#.............#............#................#..........#.#.#.....................#............#.....................#......','......................#.........................#.................#...........................#................#..................','...#....#..........................#.#..##.................#..#..........#..............................................#.........','...........#.........................................................................................#.............#..............','..............#.................##...........#..#.............................................#..............................#....','...............................................##.......#..#.....#........#...#.............#.....................#...............','........#...................#...........#...............................#............................................#........#...','...................................#.....#......................#...#.........##..#...................#.#.........................','............#...........##............#.......................#.....#.......#...................#.................................','..#..#..............................#.......#.........#.....................................#.............#..#.................#..','..................#..................#..........................##..................#...#.......#.........#..................#....','.........#.........#..............................................#...........................................................#...','......................#...........#..................................#............................#......#.....#..................','.....#....#......#..................#.....#..............#.............................................#.....#....................','..............##...........#........................................................................#........#.#..................','..........#...............................##.......#............#.#.........#.....................................#....#..........','.................................#..............#.............................#........................................#..........','....................#.................#..........#..............#.......................#...................................#.....','............#..............................#.............................#......#......#......................#...#...............','.#..........#...............#..................................................................#....#.............................','....#............................................#......#..................#.....#............#.........................#.........']

heighth = len(map)
print('The room height is:',heighth)

width = len(map[0])
print('The room width is:',width)

guardCharacters = "^><v"

def paintSpot(location):
    x = location[0]
    y = location[1]
    paintedRow = paintedMap[y-1]
    paintedRow[x-1] = True

def guardLocation(inputMap):
    for guardCharacter in guardCharacters:
        y = 0
        #print(guardCharacter)
        
        for row in inputMap:
            x = row.find(guardCharacter)
            if x > -1:
                #print(x, y)
                paintSpot((x,y))
                return(x, y)
            y = y + 1
            #print('There is no guard in this row')
    return 'There is no guard in this room'

def makeSecondMap(x, y):
    secondMapList = []
    for number in range(y):
        row = []
        for item in range(x):
            row.append(False)
            
        secondMapList.append(row)
    return secondMapList

def paintedSpotCount(paintedMap):
    totalPaintedSpots = 0
    for row in paintedMap:
        for spot in row:
            if spot is True:
                totalPaintedSpots += 1
                #print("Guard location spot found") degbugging
            #else:
                #print("Guard location spot not found") degbugging
    return totalPaintedSpots   

def characterAtLocation(location):
    x = location[0]
    y = location[1]
    row = map[y]
    char = row[x]
    return char

def obstacleAt(location):
    char = characterAtLocation(location)
    if char == '#':
        return True
    else:
        return False

def nextGuardLocation(location, guardCharacter):
    x = location[0]
    y = location[1]
    if guardCharacter == '^':
        return x, y-1
    elif guardCharacter == '>':
        return x+1, y
    elif guardCharacter == 'v':
        return x, y+1
    elif guardCharacter == '<':
        return x-1, y

def replaceCharacterInMap(location, newCharacter):
    x = location[0]
    y = location[1]
    row = map[y]
    newRow = row[:x] + newCharacter + row[x + 1:]
    map[y] = newRow

def guardRotation():
    currentLocation = guardLocation(map)
    guardCharacter = characterAtLocation(currentLocation)
    
    if guardCharacter == '^':
        guardCharacter = '>'
    elif guardCharacter == '>':
        guardCharacter = 'v'
    elif guardCharacter == 'v':
        guardCharacter = '<'
    elif guardCharacter == '<':
        guardCharacter = '^'
        
    replaceCharacterInMap(currentLocation, guardCharacter)

def isThisLocationOnTheMap(location):
    x = location[0]
    y = location[1]
    if x < 0:
        return False
    if y < 0:
        return False
    if x >= width:
        return False
    if y >= heighth:
        return False
    
    return True

paintedMap = makeSecondMap(width, heighth)

while True:
    currentLocation = guardLocation(map)
    guardCharacter = characterAtLocation(currentLocation)
    nextLocation = nextGuardLocation(currentLocation, guardCharacter)
    if isThisLocationOnTheMap(nextLocation) is False:
        break
        
    blocked = obstacleAt(nextLocation)
    print('The guard is at', currentLocation)
    print('Next guard location is', nextLocation)
    print('Next location is on the map:', isThisLocationOnTheMap(nextLocation))
    print('Obstacle at this location?', blocked)


    if blocked == True:
        guardRotation()
    else:
        replaceCharacterInMap(nextLocation, guardCharacter)
        paintSpot(nextLocation)
        #print(map)
        replaceCharacterInMap(currentLocation, '.')
        #print(map)
    
print('The guard has been to', paintedSpotCount(paintedMap), 'spots')
# Out:
# The room height is: 130
# The room width is: 130
# The guard is at (95, 67)
# Next guard location is (95, 66)
# Next location is on the map: True
# Obstacle at this location? False
# The guard is at (95, 66)
# Next guard location is (95, 65)
# Next location is on the map: True
# Obstacle at this location? False
# The guard is at (95, 65)
# Next guard location is (95, 64)
# Next location is on the map: True
# Obstacle at this location? False
# The guard is at (95, 64)
# Next guard location is (95, 63)
# Next location is on the map: True
# Obstacle at this location? False
# The guard is at (95, 63)
# Next guard location is (95, 62)
# Next location is on the map: True
# Obstacle at this location? False
# The guard is at (95, 62)
# Next guard location is (95, 61)
# Next location is on the map: True
# Obstacle at this location? False
# The guard is at (95, 61)
# Next guard location is (95, 60)
# Next location is on the map: True
# Obstacle at this location? False
# The guard is at (95, 60)
# Next guard location is (95, 59)
# Next location is on the map: True
# Obstacle at this location? False
# The guard is at (95, 59)
# Next guard location is (95, 58)
# Next location is on the map: True
# Obstacle at this location? False
# The guard is at (95, 58)
# Next guard location is (95, 57)
# Next location is on the map: True
# Obstacle at this location? False
# The guard is at (95, 57)
# Next guard location is (95, 56)
# Next location is on the map: True
# Obstacle at this location? False
# The guard is at (95, 56)
# Next guard location is (95, 55)
# Next location is on the map: True
# Obstacle at this location? False
# The guard is at (95, 55)
# Next guard location is (95, 54)
# Next location is on the map: True
# Obstacle at this location? False
# The guard is at (95, 54)
# Next guard location is (95, 53)
# Next location is on the map: True
# Obstacle at this location? False
# The guard is at (95, 53)
# Next guard location is (95, 52)
# Next location is on the map: True
# Obstacle at this location? False
# The guard is at (95, 52)
# Next guard location is (95, 51)
# Next location is on the map: True
# Obstacle at this location? False
# The guard is at (95, 51)
# Next guard location is (95, 50)
# Next location is on the map: True
# Obstacle at this location? False
# The guard is at (95, 50)
# Next guard location is (95, 49)
# Next location is on the map: True
# Obstacle at this location? False
# The guard is at (95, 49)
# Next guard location is (95, 48)
# Next location is on the map: True
# Obstacle at this location? False
# The guard is at (95, 48)
# Next guard location is (95, 47)
# Next location is on the map: True
# Obstacle at this location? False
# The guard is at (95, 47)
# Next guard location is (95, 46)
# Next location is on the map: True
# Obstacle at this location? False
# The guard is at (95, 46)
# Next guard location is (95, 45)
# Next location is on the map: True
# Obstacle at this location? False
# The guard is at (95, 45)
# Next guard location is (95, 44)
# Next location is on the map: True
# Obstacle at this location? False
# The guard is at (95, 44)
# Next guard location is (95, 43)
# Next location is on the map: True
# Obstacle at this location? False
# The guard is at (95, 43)
# Next guard location is (95, 42)
# Next location is on the map: True
# Obstacle at this location? False
# The guard is at (95, 42)
# Next guard location is (95, 41)
# Next location is on the map: True
# Obstacle at this location? False
# The guard is at (95, 41)
# Next guard location is (95, 40)
# Next location is on the map: True
# Obstacle at this location? False
# The guard is at (95, 40)
# Next guard location is (95, 39)
# Next location is on the map: True
# Obstacle at this location? False
# The guard is at (95, 39)
# Next guard location is (95, 38)
# Next location is on the map: True
# Obstacle at this location? False
# The guard is at (95, 38)
# Next guard location is (95, 37)
# Next location is on the map: True
# Obstacle at this location? False
# The guard is at (95, 37)
# Next guard location is (95, 36)
# Next location is on the map: True
# Obstacle at this location? False
# The guard is at (95, 36)
# Next guard location is (95, 35)
# Next location is on the map: True
# Obstacle at this location? False
# The guard is at (95, 35)
# Next guard location is (95, 34)
# Next location is on the map: True
# Obstacle at this location? False
# The guard is at (95, 34)
# Next guard location is (95, 33)
# Next location is on the map: True
# Obstacle at this location? False
# The guard is at (95, 33)
# Next guard location is (95, 32)
# Next location is on the map: True
# Obstacle at this location? False
# The guard is at (95, 32)
# Next guard location is (95, 31)
# Next location is on the map: True
# Obstacle at this location? False
# The guard is at (95, 31)
# Next guard location is (95, 30)
# Next location is on the map: True
# Obstacle at this location? False
# The guard is at (95, 30)
# Next guard location is (95, 29)
# Next location is on the map: True
# Obstacle at this location? True
# The guard is at (95, 30)
# Next guard location is (96, 30)
# Next location is on the map: True
# Obstacle at this location? False
# The guard is at (96, 30)
# Next guard location is (97, 30)
# Next location is on the map: True
# Obstacle at this location? False
# The guard is at (97, 30)
# Next guard location is (98, 30)
# Next location is on the map: True
# Obstacle at this location? False
# The guard is at (98, 30)
# Next guard location is (99, 30)
# Next location is on the map: True
# Obstacle at this location? False
# The guard is at (99, 30)
# Next guard location is (100, 30)
# Next location is on the map: True
# Obstacle at this location? False
# The guard is at (100, 30)
# Next guard location is (101, 30)
# Next location is on the map: True
# Obstacle at this location? False
# The guard is at (101, 30)
# Next guard location is (102, 30)
# Next location is on the map: True
# Obstacle at this location? False
# The guard is at (102, 30)
# Next guard location is (103, 30)
# Next location is on the map: True
# Obstacle at this location? False
# The guard is at (103, 30)
# Next guard location is (104, 30)
# Next location is on the map: True
# Obstacle at this location? False
# The guard is at (104, 30)
# Next guard location is (105, 30)
# Next location is on the map: True
# Obstacle at this location? False
# The guard is at (105, 30)
# Next guard location is (106, 30)
# Next location is on the map: True
# Obstacle at this location? False
# The guard is at (106, 30)
# Next guard location is (107, 30)
# Next location is on the map: True
# Obstacle at this location? False
# The guard is at (107, 30)
# Next guard location is (108, 30)
# Next location is on the map: True
# Obstacle at this location? False
# The guard is at (108, 30)
# Next guard location is (109, 30)
# Next location is on the map: True
# Obstacle at this location? True
# The guard is at (108, 30)
# Next guard location is (108, 31)
# Next location is on the map: True
# Obstacle at this location? False
# The guard is at (108, 31)
# Next guard location is (108, 32)
# Next location is on the map: True
# Obstacle at this location? False
# The guard is at (108, 32)
# Next guard location is (108, 33)
# Next location is on the map: True
# Obstacle at this location? False
# The guard is at (108, 33)
# Next guard location is (108, 34)
# Next location is on the map: True
# Obstacle at this location? False
# The guard is at (108, 34)
# Next guard location is (108, 35)
# Next location is on the map: True
# Obstacle at this location? False
# The guard is at (108, 35)
# Next guard location is (108, 36)
# Next location is on the map: True
# Obstacle at this location? False
# The guard is at (108, 36)
# Next guard location is (108, 37)
# Next location is on the map: True
# Obstacle at this location? False
# The guard is at (108, 37)
# Next guard location is (108, 38)
# Next location is on the map: True
# Obstacle at this location? False
# The guard is at (108, 38)
# Next guard location is (108, 39)
# Next location is on the map: True
# Obstacle at this location? False
# The guard is at (108, 39)
# Next guard location is (108, 40)
# Next location is on the map: True
# Obstacle at this location? False
# The guard is at (108, 40)
# Next guard location is (108, 41)
# Next location is on the map: True
# Obstacle at this location? False
# The guard is at (108, 41)
# Next guard location is (108, 42)
# Next location is on the map: True
# Obstacle at this location? False
# The guard is at (108, 42)
# Next guard location is (108, 43)
# Next location is on the map: True
# Obstacle at this location? False
# The guard is at (108, 43)
# Next guard location is (108, 44)
# Next location is on the map: True
# Obstacle at this location? False
# The guard is at (108, 44)
# Next guard location is (108, 45)
# Next location is on the map: True
# Obstacle at this location? False
# The guard is at (108, 45)
# Next guard location is (108, 46)
# Next location is on the map: True
# Obstacle at this location? False
# The guard is at (108, 46)
# Next guard location is (108, 47)
# Next location is on the map: True
# Obstacle at this location? False
# The guard is at (108, 47)
# Next guard location is (108, 48)
# Next location is on the map: True
# Obstacle at this location? False
# The guard is at (108, 48)
# Next guard location is (108, 49)
# Next location is on the map: True
# Obstacle at this location? False
# The guard is at (108, 49)
# Next guard location is (108, 50)
# Next location is on the map: True
# Obstacle at this location? False
# The guard is at (108, 50)
# Next guard location is (108, 51)
# Next location is on the map: True
# Obstacle at this location? False
# The guard is at (108, 51)
# Next guard location is (108, 52)
# Next location is on the map: True
# Obstacle at this location? False
# The guard is at (108, 52)
# Next guard location is (108, 53)
# Next location is on the map: True
# Obstacle at this location? False
# The guard is at (108, 53)
# Next guard location is (108, 54)
# Next location is on the map: True
# Obstacle at this location? False
# The guard is at (108, 54)
# Next guard location is (108, 55)
# Next location is on the map: True
# Obstacle at this location? True
# The guard is at (108, 54)
# Next guard location is (107, 54)
# Next location is on the map: True
# Obstacle at this location? False
# The guard is at (107, 54)
# Next guard location is (106, 54)
# Next location is on the map: True
# Obstacle at this location? False
# The guard is at (106, 54)
# Next guard location is (105, 54)
# Next location is on the map: True
# Obstacle at this location? False
# The guard is at (105, 54)
# Next guard location is (104, 54)
# Next location is on the map: True
# Obstacle at this location? False
# The guard is at (104, 54)
# Next guard location is (103, 54)
# Next location is on the map: True
# Obstacle at this location? False
# The guard is at (103, 54)
# Next guard location is (102, 54)
# Next location is on the map: True
# Obstacle at this location? False
# The guard is at (102, 54)
# Next guard location is (101, 54)
# Next location is on the map: True
# Obstacle at this location? False
# The guard is at (101, 54)
# Next guard location is (100, 54)
# Next location is on the map: True
# Obstacle at this location? False
# The guard is at (100, 54)
# Next guard location is (99, 54)
# Next location is on the map: True
# Obstacle at this location? False
# The guard is at (99, 54)
# Next guard location is (98, 54)
# Next location is on the map: True
# Obstacle at this location? False
# The guard is at (98, 54)
# Next guard location is (97, 54)
# Next location is on the map: True
# Obstacle at this location? False
# The guard is at (97, 54)
# Next guard location is (96, 54)
# Next location is on the map: True
# Obstacle at this location? False
# The guard is at (96, 54)
# Next guard location is (95, 54)
# Next location is on the map: True
# Obstacle at this location? False
# The guard is at (95, 54)
# Next guard location is (94, 54)
# Next location is on the map: True
# Obstacle at this location? False
# The guard is at (94, 54)
# Next guard location is (93, 54)
# Next location is on the map: True
# Obstacle at this location? False
# The guard is at (93, 54)
# Next guard location is (92, 54)
# Next location is on the map: True
# Obstacle at this location? False
# The guard is at (92, 54)
# Next guard location is (91, 54)
# Next location is on the map: True
# Obstacle at this location? False
# The guard is at (91, 54)
# Next guard location is (90, 54)
# Next location is on the map: True
# Obstacle at this location? False
# The guard is at (90, 54)
# Next guard location is (89, 54)
# Next location is on the map: True
# Obstacle at this location? False
# The guard is at (89, 54)
# Next guard location is (88, 54)
# Next location is on the map: True
# Obstacle at this location? False
# The guard is at (88, 54)
# Next guard location is (87, 54)
# Next location is on the map: True
# Obstacle at this location? True
# The guard is at (88, 54)
# Next guard location is (88, 53)
# Next location is on the map: True
# Obstacle at this location? False
# The guard is at (88, 53)
# Next guard location is (88, 52)
# Next location is on the map: True
# Obstacle at this location? False
# The guard is at (88, 52)
# Next guard location is (88, 51)
# Next location is on the map: True
# Obstacle at this location? False
# The guard is at (88, 51)
# Next guard location is (88, 50)
# Next location is on the map: True
# Obstacle at this location? False
# The guard is at (88, 50)
# Next guard location is (88, 49)
# Next location is on the map: True
# Obstacle at this location? False
# The guard is at (88, 49)
# Next guard location is (88, 48)
# Next location is on the map: True
# Obstacle at this location? False
# The guard is at (88, 48)
# Next guard location is (88, 47)
# Next location is on the map: True
# Obstacle at this location? False
# The guard is at (88, 47)
# Next guard location is (88, 46)
# Next location is on the map: True
# Obstacle at this location? False
# The guard is at (88, 46)
# Next guard location is (88, 45)
# Next location is on the map: True
# Obstacle at this location? False
# The guard is at (88, 45)
# Next guard location is (88, 44)
# Next location is on the map: True
# Obstacle at this location? False
# The guard is at (88, 44)
# Next guard location is (88, 43)
# Next location is on the map: True
# Obstacle at this location? False
# The guard is at (88, 43)
# Next guard location is (88, 42)
# Next location is on the map: True
# Obstacle at this location? False
# The guard is at (88, 42)
# Next guard location is (88, 41)
# Next location is on the map: True
# Obstacle at this location? False
# The guard is at (88, 41)
# Next guard location is (88, 40)
# Next location is on the map: True
# Obstacle at this location? False
# The guard is at (88, 40)
# Next guard location is (88, 39)
# Next location is on the map: True
# Obstacle at this location? False
# The guard is at (88, 39)
# Next guard location is (88, 38)
# Next location is on the map: True
# Obstacle at this location? False
# The guard is at (88, 38)
# Next guard location is (88, 37)
# Next location is on the map: True
# Obstacle at this location? False
# The guard is at (88, 37)
# Next guard location is (88, 36)
# Next location is on the map: True
# Obstacle at this location? False
# The guard is at (88, 36)
# Next guard location is (88, 35)
# Next location is on the map: True
# Obstacle at this location? False
# The guard is at (88, 35)
# Next guard location is (88, 34)
# Next location is on the map: True
# Obstacle at this location? False
# The guard is at (88, 34)
# Next guard location is (88, 33)
# Next location is on the map: True
# Obstacle at this location? False
# The guard is at (88, 33)
# Next guard location is (88, 32)
# Next location is on the map: True
# Obstacle at this location? False
# The guard is at (88, 32)
# Next guard location is (88, 31)
# Next location is on the map: True
# Obstacle at this location? False
# The guard is at (88, 31)
# Next guard location is (88, 30)
# Next location is on the map: True
# Obstacle at this location? False
# The guard is at (88, 30)
# Next guard location is (88, 29)
# Next location is on the map: True
# Obstacle at this location? False
# The guard is at (88, 29)
# Next guard location is (88, 28)
# Next location is on the map: True
# Obstacle at this location? False
# The guard is at (88, 28)
# Next guard location is (88, 27)
# Next location is on the map: True
# Obstacle at this location? False
# The guard is at (88, 27)
# Next guard location is (88, 26)
# Next location is on the map: True
# Obstacle at this location? False
# The guard is at (88, 26)
# Next guard location is (88, 25)
# Next location is on the map: True
# Obstacle at this location? False
# The guard is at (88, 25)
# Next guard location is (88, 24)
# Next location is on the map: True
# Obstacle at this location? False
# The guard is at (88, 24)
# Next guard location is (88, 23)
# Next location is on the map: True
# Obstacle at this location? False
# The guard is at (88, 23)
# Next guard location is (88, 22)
# Next location is on the map: True
# Obstacle at this location? False
# The guard is at (88, 22)
# Next guard location is (88, 21)
# Next location is on the map: True
# Obstacle at this location? False
# The guard is at (88, 21)
# Next guard location is (88, 20)
# Next location is on the map: True
# Obstacle at this location? False
# The guard is at (88, 20)
# Next guard location is (88, 19)
# Next location is on the map: True
# Obstacle at this location? False
# The guard is at (88, 19)
# Next guard location is (88, 18)
# Next location is on the map: True
# Obstacle at this location? False
# The guard is at (88, 18)
# Next guard location is (88, 17)
# Next location is on the map: True
# Obstacle at this location? False
# The guard is at (88, 17)
# Next guard location is (88, 16)
# Next location is on the map: True
# Obstacle at this location? False
# The guard is at (88, 16)
# Next guard location is (88, 15)
# Next location is on the map: True
# Obstacle at this location? False
# The guard is at (88, 15)
# Next guard location is (88, 14)
# Next location is on the map: True
# Obstacle at this location? False
# The guard is at (88, 14)
# Next guard location is (88, 13)
# Next location is on the map: True
# Obstacle at this location? True
# The guard is at (88, 14)
# Next guard location is (89, 14)
# Next location is on the map: True
# Obstacle at this location? False
# The guard is at (89, 14)
# Next guard location is (90, 14)
# Next location is on the map: True
# Obstacle at this location? False
# The guard is at (90, 14)
# Next guard location is (91, 14)
# Next location is on the map: True
# Obstacle at this location? False
# The guard is at (91, 14)
# Next guard location is (92, 14)
# Next location is on the map: True
# Obstacle at this location? False
# The guard is at (92, 14)
# Next guard location is (93, 14)
# Next location is on the map: True
# Obstacle at this location? False
# The guard is at (93, 14)
# Next guard location is (94, 14)
# Next location is on the map: True
# Obstacle at this location? False
# The guard is at (94, 14)
# Next guard location is (95, 14)
# Next location is on the map: True
# Obstacle at this location? False
# The guard is at (95, 14)
# Next guard location is (96, 14)
# Next location is on the map: True
# Obstacle at this location? False
# The guard is at (96, 14)
# Next guard location is (97, 14)
# Next location is on the map: True
# Obstacle at this location? False
# The guard is at (97, 14)
# Next guard location is (98, 14)
# Next location is on the map: True
# Obstacle at this location? False
# The guard is at (98, 14)
# Next guard location is (99, 14)
# Next location is on the map: True
# Obstacle at this location? False
# The guard is at (99, 14)
# Next guard location is (100, 14)
# Next location is on the map: True
# Obstacle at this location? False
# The guard is at (100, 14)
# Next guard location is (101, 14)
# Next location is on the map: True
# Obstacle at this location? False
# The guard is at (101, 14)
# Next guard location is (102, 14)
# Next location is on the map: True
# Obstacle at this location? False
# The guard is at (102, 14)
# Next guard location is (103, 14)
# Next location is on the map: True
# Obstacle at this location? False
# The guard is at (103, 14)
# Next guard location is (104, 14)
# Next location is on the map: True
# Obstacle at this location? False
# The guard is at (104, 14)
# Next guard location is (105, 14)
# Next location is on the map: True
# Obstacle at this location? False
# The guard is at (105, 14)
# Next guard location is (106, 14)
# Next location is on the map: True
# Obstacle at this location? False
# The guard is at (106, 14)
# Next guard location is (107, 14)
# Next location is on the map: True
# Obstacle at this location? False
# The guard is at (107, 14)
# Next guard location is (108, 14)
# Next location is on the map: True
# Obstacle at this location? False
# The guard is at (108, 14)
# Next guard location is (109, 14)
# Next location is on the map: True
# Obstacle at this location? False
# The guard is at (109, 14)
# Next guard location is (110, 14)
# Next location is on the map: True
# Obstacle at this location? False
# The guard is at (110, 14)
# Next guard location is (111, 14)
# Next location is on the map: True
# Obstacle at this location? False
# The guard is at (111, 14)
# Next guard location is (112, 14)
# Next location is on the map: True
# Obstacle at this location? True
# The guard is at (111, 14)
# Next guard location is (111, 15)
# Next location is on the map: True
# Obstacle at this location? False
# The guard is at (111, 15)
# Next guard location is (111, 16)
# Next location is on the map: True
# Obstacle at this location? False
# The guard is at (111, 16)
# Next guard location is (111, 17)
# Next location is on the map: True
# Obstacle at this location? False
# The guard is at (111, 17)
# Next guard location is (111, 18)
# Next location is on the map: True
# Obstacle at this location? False
# The guard is at (111, 18)
# Next guard location is (111, 19)
# Next location is on the map: True
# Obstacle at this location? False
# The guard is at (111, 19)
# Next guard location is (111, 20)
# Next location is on the map: True
# Obstacle at this location? False
# The guard is at (111, 20)
# Next guard location is (111, 21)
# Next location is on the map: True
# Obstacle at this location? False
# The guard is at (111, 21)
# Next guard location is (111, 22)
# Next location is on the map: True
# Obstacle at this location? False
# The guard is at (111, 22)
# Next guard location is (111, 23)
# Next location is on the map: True
# Obstacle at this location? False
# The guard is at (111, 23)
# Next guard location is (111, 24)
# Next location is on the map: True
# Obstacle at this location? False
# The guard is at (111, 24)
# Next guard location is (111, 25)
# Next location is on the map: True
# Obstacle at this location? False
# The guard is at (111, 25)
# Next guard location is (111, 26)
# Next location is on the map: True
# Obstacle at this location? False
# The guard is at (111, 26)
# Next guard location is (111, 27)
# Next location is on the map: True
# Obstacle at this location? False
# The guard is at (111, 27)
# Next guard location is (111, 28)
# Next location is on the map: True
# Obstacle at this location? False
# The guard is at (111, 28)
# Next guard location is (111, 29)
# Next location is on the map: True
# Obstacle at this location? False
# The guard is at (111, 29)
# Next guard location is (111, 30)
# Next location is on the map: True
# Obstacle at this location? False
# The guard is at (111, 30)
# Next guard location is (111, 31)
# Next location is on the map: True
# Obstacle at this location? False
# The guard is at (111, 31)
# Next guard location is (111, 32)
# Next location is on the map: True
# Obstacle at this location? False
# The guard is at (111, 32)
# Next guard location is (111, 33)
# Next location is on the map: True
# Obstacle at this location? False
# The guard is at (111, 33)
# Next guard location is (111, 34)
# Next location is on the map: True
# Obstacle at this location? False
# The guard is at (111, 34)
# Next guard location is (111, 35)
# Next location is on the map: True
# Obstacle at this location? False
# The guard is at (111, 35)
# Next guard location is (111, 36)
# Next location is on the map: True
# Obstacle at this location? False
# The guard is at (111, 36)
# Next guard location is (111, 37)
# Next location is on the map: True
# Obstacle at this location? False
# The guard is at (111, 37)
# Next guard location is (111, 38)
# Next location is on the map: True
# Obstacle at this location? False
# The guard is at (111, 38)
# Next guard location is (111, 39)
# Next location is on the map: True
# Obstacle at this location? False
# The guard is at (111, 39)
# Next guard location is (111, 40)
# Next location is on the map: True
# Obstacle at this location? False
# The guard is at (111, 40)
# Next guard location is (111, 41)
# Next location is on the map: True
# Obstacle at this location? False
# The guard is at (111, 41)
# Next guard location is (111, 42)
# Next location is on the map: True
# Obstacle at this location? False
# The guard is at (111, 42)
# Next guard location is (111, 43)
# Next location is on the map: True
# Obstacle at this location? False
# The guard is at (111, 43)
# Next guard location is (111, 44)
# Next location is on the map: True
# Obstacle at this location? False
# The guard is at (111, 44)
# Next guard location is (111, 45)
# Next location is on the map: True
# Obstacle at this location? False
# The guard is at (111, 45)
# Next guard location is (111, 46)
# Next location is on the map: True
# Obstacle at this location? False
# The guard is at (111, 46)
# Next guard location is (111, 47)
# Next location is on the map: True
# Obstacle at this location? False
# The guard is at (111, 47)
# Next guard location is (111, 48)
# Next location is on the map: True
# Obstacle at this location? False
# The guard is at (111, 48)
# Next guard location is (111, 49)
# Next location is on the map: True
# Obstacle at this location? False
# The guard is at (111, 49)
# Next guard location is (111, 50)
# Next location is on the map: True
# Obstacle at this location? False
# The guard is at (111, 50)
# Next guard location is (111, 51)
# Next location is on the map: True
# Obstacle at this location? False
# The guard is at (111, 51)
# Next guard location is (111, 52)
# Next location is on the map: True
# Obstacle at this location? False
# The guard is at (111, 52)
# Next guard location is (111, 53)
# Next location is on the map: True
# Obstacle at this location? False
# The guard is at (111, 53)
# Next guard location is (111, 54)
# Next location is on the map: True
# Obstacle at this location? False
# The guard is at (111, 54)
# Next guard location is (111, 55)
# Next location is on the map: True
# Obstacle at this location? False
# The guard is at (111, 55)
# Next guard location is (111, 56)
# Next location is on the map: True
# Obstacle at this location? False
# The guard is at (111, 56)
# Next guard location is (111, 57)
# Next location is on the map: True
# Obstacle at this location? False
# The guard is at (111, 57)
# Next guard location is (111, 58)
# Next location is on the map: True
# Obstacle at this location? True
# The guard is at (111, 57)
# Next guard location is (110, 57)
# Next location is on the map: True
# Obstacle at this location? False
# The guard is at (110, 57)
# Next guard location is (109, 57)
# Next location is on the map: True
# Obstacle at this location? False
# The guard is at (109, 57)
# Next guard location is (108, 57)
# Next location is on the map: True
# Obstacle at this location? False
# The guard is at (108, 57)
# Next guard location is (107, 57)
# Next location is on the map: True
# Obstacle at this location? False
# The guard is at (107, 57)
# Next guard location is (106, 57)
# Next location is on the map: True
# Obstacle at this location? False
# The guard is at (106, 57)
# Next guard location is (105, 57)
# Next location is on the map: True
# Obstacle at this location? False
# The guard is at (105, 57)
# Next guard location is (104, 57)
# Next location is on the map: True
# Obstacle at this location? False
# The guard is at (104, 57)
# Next guard location is (103, 57)
# Next location is on the map: True
# Obstacle at this location? False
# The guard is at (103, 57)
# Next guard location is (102, 57)
# Next location is on the map: True
# Obstacle at this location? False
# The guard is at (102, 57)
# Next guard location is (101, 57)
# Next location is on the map: True
# Obstacle at this location? False
# The guard is at (101, 57)
# Next guard location is (100, 57)
# Next location is on the map: True
# Obstacle at this location? False
# The guard is at (100, 57)
# Next guard location is (99, 57)
# Next location is on the map: True
# Obstacle at this location? False
# The guard is at (99, 57)
# Next guard location is (98, 57)
# Next location is on the map: True
# Obstacle at this location? False
# The guard is at (98, 57)
# Next guard location is (97, 57)
# Next location is on the map: True
# Obstacle at this location? False
# The guard is at (97, 57)
# Next guard location is (96, 57)
# Next location is on the map: True
# Obstacle at this location? False
# The guard is at (96, 57)
# Next guard location is (95, 57)
# Next location is on the map: True
# Obstacle at this location? False
# The guard is at (95, 57)
# Next guard location is (94, 57)
# Next location is on the map: True
# Obstacle at this location? False
# The guard is at (94, 57)
# Next guard location is (93, 57)
# Next location is on the map: True
# Obstacle at this location? False
# The guard is at (93, 57)
# Next guard location is (92, 57)
# Next location is on the map: True
# Obstacle at this location? False
# The guard is at (92, 57)
# Next guard location is (91, 57)
# Next location is on the map: True
# Obstacle at this location? False
# The guard is at (91, 57)
# Next guard location is (90, 57)
# Next location is on the map: True
# Obstacle at this location? False
# The guard is at (90, 57)
# Next guard location is (89, 57)
# Next location is on the map: True
# Obstacle at this location? False
# The guard is at (89, 57)
# Next guard location is (88, 57)
# Next location is on the map: True
# Obstacle at this location? False
# The guard is at (88, 57)
# Next guard location is (87, 57)
# Next location is on the map: True
# Obstacle at this location? False
# The guard is at (87, 57)
# Next guard location is (86, 57)
# Next location is on the map: True
# Obstacle at this location? False
# The guard is at (86, 57)
# Next guard location is (85, 57)
# Next location is on the map: True
# Obstacle at this location? False
# The guard is at (85, 57)
# Next guard location is (84, 57)
# Next location is on the map: True
# Obstacle at this location? False
# The guard is at (84, 57)
# Next guard location is (83, 57)
# Next location is on the map: True
# Obstacle at this location? False
# The guard is at (83, 57)
# Next guard location is (82, 57)
# Next location is on the map: True
# Obstacle at this location? False
# The guard is at (82, 57)
# Next guard location is (81, 57)
# Next location is on the map: True
# Obstacle at this location? False
# The guard is at (81, 57)
# Next guard location is (80, 57)
# Next location is on the map: True
# Obstacle at this location? False
# The guard is at (80, 57)
# Next guard location is (79, 57)
# Next location is on the map: True
# Obstacle at this location? False
# The guard is at (79, 57)
# Next guard location is (78, 57)
# Next location is on the map: True
# Obstacle at this location? False
# The guard is at (78, 57)
# Next guard location is (77, 57)
# Next location is on the map: True
# Obstacle at this location? False
# The guard is at (77, 57)
# Next guard location is (76, 57)
# Next location is on the map: True
# Obstacle at this location? False
# The guard is at (76, 57)
# Next guard location is (75, 57)
# Next location is on the map: True
# Obstacle at this location? False
# The guard is at (75, 57)
# Next guard location is (74, 57)
# Next location is on the map: True
# Obstacle at this location? False
# The guard is at (74, 57)
# Next guard location is (73, 57)
# Next location is on the map: True
# Obstacle at this location? False
# The guard is at (73, 57)
# Next guard location is (72, 57)
# Next location is on the map: True
# Obstacle at this location? False
# The guard is at (72, 57)
# Next guard location is (71, 57)
# Next location is on the map: True
# Obstacle at this location? False
# The guard is at (71, 57)
# Next guard location is (70, 57)
# Next location is on the map: True
# Obstacle at this location? False
# The guard is at (70, 57)
# Next guard location is (69, 57)
# Next location is on the map: True
# Obstacle at this location? False
# The guard is at (69, 57)
# Next guard location is (68, 57)
# Next location is on the map: True
# Obstacle at this location? False
# The guard is at (68, 57)
# Next guard location is (67, 57)
# Next location is on the map: True
# Obstacle at this location? False
# The guard is at (67, 57)
# Next guard location is (66, 57)
# Next location is on the map: True
# Obstacle at this location? False
# The guard is at (66, 57)
# Next guard location is (65, 57)
# Next location is on the map: True
# Obstacle at this location? False
# The guard is at (65, 57)
# Next guard location is (64, 57)
# Next location is on the map: True
# Obstacle at this location? False
# The guard is at (64, 57)
# Next guard location is (63, 57)
# Next location is on the map: True
# Obstacle at this location? False
# The guard is at (63, 57)
# Next guard location is (62, 57)
# Next location is on the map: True
# Obstacle at this location? False
# The guard is at (62, 57)
# Next guard location is (61, 57)
# Next location is on the map: True
# Obstacle at this location? False
# The guard is at (61, 57)
# Next guard location is (60, 57)
# Next location is on the map: True
# Obstacle at this location? False
# The guard is at (60, 57)
# Next guard location is (59, 57)
# Next location is on the map: True
# Obstacle at this location? False
# The guard is at (59, 57)
# Next guard location is (58, 57)
# Next location is on the map: True
# Obstacle at this location? False
# The guard is at (58, 57)
# Next guard location is (57, 57)
# Next location is on the map: True
# Obstacle at this location? False
# The guard is at (57, 57)
# Next guard location is (56, 57)
# Next location is on the map: True
# Obstacle at this location? False
# The guard is at (56, 57)
# Next guard location is (55, 57)
# Next location is on the map: True
# Obstacle at this location? False
# The guard is at (55, 57)
# Next guard location is (54, 57)
# Next location is on the map: True
# Obstacle at this location? False
# The guard is at (54, 57)
# Next guard location is (53, 57)
# Next location is on the map: True
# Obstacle at this location? False
# The guard is at (53, 57)
# Next guard location is (52, 57)
# Next location is on the map: True
# Obstacle at this location? False
# The guard is at (52, 57)
# Next guard location is (51, 57)
# Next location is on the map: True
# Obstacle at this location? False
# The guard is at (51, 57)
# Next guard location is (50, 57)
# Next location is on the map: True
# Obstacle at this location? False
# The guard is at (50, 57)
# Next guard location is (49, 57)
# Next location is on the map: True
# Obstacle at this location? False
# The guard is at (49, 57)
# Next guard location is (48, 57)
# Next location is on the map: True
# Obstacle at this location? False
# The guard is at (48, 57)
# Next guard location is (47, 57)
# Next location is on the map: True
# Obstacle at this location? False
# The guard is at (47, 57)
# Next guard location is (46, 57)
# Next location is on the map: True
# Obstacle at this location? False
# The guard is at (46, 57)
# Next guard location is (45, 57)
# Next location is on the map: True
# Obstacle at this location? False
# The guard is at (45, 57)
# Next guard location is (44, 57)
# Next location is on the map: True
# Obstacle at this location? False
# The guard is at (44, 57)
# Next guard location is (43, 57)
# Next location is on the map: True
# Obstacle at this location? False
# The guard is at (43, 57)
# Next guard location is (42, 57)
# Next location is on the map: True
# Obstacle at this location? True
# The guard is at (43, 57)
# Next guard location is (43, 56)
# Next location is on the map: True
# Obstacle at this location? False
# The guard is at (43, 56)
# Next guard location is (43, 55)
# Next location is on the map: True
# Obstacle at this location? False
# The guard is at (43, 55)
# Next guard location is (43, 54)
# Next location is on the map: True
# Obstacle at this location? False
# The guard is at (43, 54)
# Next guard location is (43, 53)
# Next location is on the map: True
# Obstacle at this location? False
# The guard is at (43, 53)
# Next guard location is (43, 52)
# Next location is on the map: True
# Obstacle at this location? False
# The guard is at (43, 52)
# Next guard location is (43, 51)
# Next location is on the map: True
# Obstacle at this location? False
# The guard is at (43, 51)
# Next guard location is (43, 50)
# Next location is on the map: True
# Obstacle at this location? False
# The guard is at (43, 50)
# Next guard location is (43, 49)
# Next location is on the map: True
# Obstacle at this location? False
# The guard is at (43, 49)
# Next guard location is (43, 48)
# Next location is on the map: True
# Obstacle at this location? False
# The guard is at (43, 48)
# Next guard location is (43, 47)
# Next location is on the map: True
# Obstacle at this location? False
# The guard is at (43, 47)
# Next guard location is (43, 46)
# Next location is on the map: True
# Obstacle at this location? False
# The guard is at (43, 46)
# Next guard location is (43, 45)
# Next location is on the map: True
# Obstacle at this location? False
# The guard is at (43, 45)
# Next guard location is (43, 44)
# Next location is on the map: True
# Obstacle at this location? False
# The guard is at (43, 44)
# Next guard location is (43, 43)
# Next location is on the map: True
# Obstacle at this location? False
# The guard is at (43, 43)
# Next guard location is (43, 42)
# Next location is on the map: True
# Obstacle at this location? False
# The guard is at (43, 42)
# Next guard location is (43, 41)
# Next location is on the map: True
# Obstacle at this location? False
# The guard is at (43, 41)
# Next guard location is (43, 40)
# Next location is on the map: True
# Obstacle at this location? False
# The guard is at (43, 40)
# Next guard location is (43, 39)
# Next location is on the map: True
# Obstacle at this location? False
# The guard is at (43, 39)
# Next guard location is (43, 38)
# Next location is on the map: True
# Obstacle at this location? False
# The guard is at (43, 38)
# Next guard location is (43, 37)
# Next location is on the map: True
# Obstacle at this location? False
# The guard is at (43, 37)
# Next guard location is (43, 36)
# Next location is on the map: True
# Obstacle at this location? False
# The guard is at (43, 36)
# Next guard location is (43, 35)
# Next location is on the map: True
# Obstacle at this location? False
# The guard is at (43, 35)
# Next guard location is (43, 34)
# Next location is on the map: True
# Obstacle at this location? False
# The guard is at (43, 34)
# Next guard location is (43, 33)
# Next location is on the map: True
# Obstacle at this location? False
# The guard is at (43, 33)
# Next guard location is (43, 32)
# Next location is on the map: True
# Obstacle at this location? False
# The guard is at (43, 32)
# Next guard location is (43, 31)
# Next location is on the map: True
# Obstacle at this location? False
# The guard is at (43, 31)
# Next guard location is (43, 30)
# Next location is on the map: True
# Obstacle at this location? False
# The guard is at (43, 30)
# Next guard location is (43, 29)
# Next location is on the map: True
# Obstacle at this location? False
# The guard is at (43, 29)
# Next guard location is (43, 28)
# Next location is on the map: True
# Obstacle at this location? False
# The guard is at (43, 28)
# Next guard location is (43, 27)
# Next location is on the map: True
# Obstacle at this location? False
# The guard is at (43, 27)
# Next guard location is (43, 26)
# Next location is on the map: True
# Obstacle at this location? False
# The guard is at (43, 26)
# Next guard location is (43, 25)
# Next location is on the map: True
# Obstacle at this location? True
# The guard is at (43, 26)
# Next guard location is (44, 26)
# Next location is on the map: True
# Obstacle at this location? False
# The guard is at (44, 26)
# Next guard location is (45, 26)
# Next location is on the map: True
# Obstacle at this location? False
# The guard is at (45, 26)
# Next guard location is (46, 26)
# Next location is on the map: True
# Obstacle at this location? False
# The guard is at (46, 26)
# Next guard location is (47, 26)
# Next location is on the map: True
# Obstacle at this location? False
# The guard is at (47, 26)
# Next guard location is (48, 26)
# Next location is on the map: True
# Obstacle at this location? False
# The guard is at (48, 26)
# Next guard location is (49, 26)
# Next location is on the map: True
# Obstacle at this location? False
# The guard is at (49, 26)
# Next guard location is (50, 26)
# Next location is on the map: True
# Obstacle at this location? False
# The guard is at (50, 26)
# Next guard location is (51, 26)
# Next location is on the map: True
# Obstacle at this location? False
# The guard is at (51, 26)
# Next guard location is (52, 26)
# Next location is on the map: True
# Obstacle at this location? False
# The guard is at (52, 26)
# Next guard location is (53, 26)
# Next location is on the map: True
# Obstacle at this location? False
# The guard is at (53, 26)
# Next guard location is (54, 26)
# Next location is on the map: True
# Obstacle at this location? False
# The guard is at (54, 26)
# Next guard location is (55, 26)
# Next location is on the map: True
# Obstacle at this location? False
# The guard is at (55, 26)
# Next guard location is (56, 26)
# Next location is on the map: True
# Obstacle at this location? False
# The guard is at (56, 26)
# Next guard location is (57, 26)
# Next location is on the map: True
# Obstacle at this location? False
# The guard is at (57, 26)
# Next guard location is (58, 26)
# Next location is on the map: True
# Obstacle at this location? False
# The guard is at (58, 26)
# Next guard location is (59, 26)
# Next location is on the map: True
# Obstacle at this location? False
# The guard is at (59, 26)
# Next guard location is (60, 26)
# Next location is on the map: True
# Obstacle at this location? False
# The guard is at (60, 26)
# Next guard location is (61, 26)
# Next location is on the map: True
# Obstacle at this location? False
# The guard is at (61, 26)
# Next guard location is (62, 26)
# Next location is on the map: True
# Obstacle at this location? False
# The guard is at (62, 26)
# Next guard location is (63, 26)
# Next location is on the map: True
# Obstacle at this location? False
# The guard is at (63, 26)
# Next guard location is (64, 26)
# Next location is on the map: True
# Obstacle at this location? False
# The guard is at (64, 26)
# Next guard location is (65, 26)
# Next location is on the map: True
# Obstacle at this location? False
# The guard is at (65, 26)
# Next guard location is (66, 26)
# Next location is on the map: True
# Obstacle at this location? False
# The guard is at (66, 26)
# Next guard location is (67, 26)
# Next location is on the map: True
# Obstacle at this location? False
# The guard is at (67, 26)
# Next guard location is (68, 26)
# Next location is on the map: True
# Obstacle at this location? False
# The guard is at (68, 26)
# Next guard location is (69, 26)
# Next location is on the map: True
# Obstacle at this location? False
# The guard is at (69, 26)
# Next guard location is (70, 26)
# Next location is on the map: True
# Obstacle at this location? True
# The guard is at (69, 26)
# Next guard location is (69, 27)
# Next location is on the map: True
# Obstacle at this location? False
# The guard is at (69, 27)
# Next guard location is (69, 28)
# Next location is on the map: True
# Obstacle at this location? False
# The guard is at (69, 28)
# Next guard location is (69, 29)
# Next location is on the map: True
# Obstacle at this location? False
# The guard is at (69, 29)
# Next guard location is (69, 30)
# Next location is on the map: True
# Obstacle at this location? False
# The guard is at (69, 30)
# Next guard location is (69, 31)
# Next location is on the map: True
# Obstacle at this location? False
# The guard is at (69, 31)
# Next guard location is (69, 32)
# Next location is on the map: True
# Obstacle at this location? False
# The guard is at (69, 32)
# Next guard location is (69, 33)
# Next location is on the map: True
# Obstacle at this location? False
# The guard is at (69, 33)
# Next guard location is (69, 34)
# Next location is on the map: True
# Obstacle at this location? False
# The guard is at (69, 34)
# Next guard location is (69, 35)
# Next location is on the map: True
# Obstacle at this location? False
# The guard is at (69, 35)
# Next guard location is (69, 36)
# Next location is on the map: True
# Obstacle at this location? False
# The guard is at (69, 36)
# Next guard location is (69, 37)
# Next location is on the map: True
# Obstacle at this location? False
# The guard is at (69, 37)
# Next guard location is (69, 38)
# Next location is on the map: True
# Obstacle at this location? False
# The guard is at (69, 38)
# Next guard location is (69, 39)
# Next location is on the map: True
# Obstacle at this location? False
# The guard is at (69, 39)
# Next guard location is (69, 40)
# Next location is on the map: True
# Obstacle at this location? False
# The guard is at (69, 40)
# Next guard location is (69, 41)
# Next location is on the map: True
# Obstacle at this location? False
# The guard is at (69, 41)
# Next guard location is (69, 42)
# Next location is on the map: True
# Obstacle at this location? False
# The guard is at (69, 42)
# Next guard location is (69, 43)
# Next location is on the map: True
# Obstacle at this location? False
# The guard is at (69, 43)
# Next guard location is (69, 44)
# Next location is on the map: True
# Obstacle at this location? False
# The guard is at (69, 44)
# Next guard location is (69, 45)
# Next location is on the map: True
# Obstacle at this location? False
# The guard is at (69, 45)
# Next guard location is (69, 46)
# Next location is on the map: True
# Obstacle at this location? False
# The guard is at (69, 46)
# Next guard location is (69, 47)
# Next location is on the map: True
# Obstacle at this location? False
# The guard is at (69, 47)
# Next guard location is (69, 48)
# Next location is on the map: True
# Obstacle at this location? False
# The guard is at (69, 48)
# Next guard location is (69, 49)
# Next location is on the map: True
# Obstacle at this location? False
# The guard is at (69, 49)
# Next guard location is (69, 50)
# Next location is on the map: True
# Obstacle at this location? False
# The guard is at (69, 50)
# Next guard location is (69, 51)
# Next location is on the map: True
# Obstacle at this location? False
# The guard is at (69, 51)
# Next guard location is (69, 52)
# Next location is on the map: True
# Obstacle at this location? False
# The guard is at (69, 52)
# Next guard location is (69, 53)
# Next location is on the map: True
# Obstacle at this location? False
# The guard is at (69, 53)
# Next guard location is (69, 54)
# Next location is on the map: True
# Obstacle at this location? False
# The guard is at (69, 54)
# Next guard location is (69, 55)
# Next location is on the map: True
# Obstacle at this location? False
# The guard is at (69, 55)
# Next guard location is (69, 56)
# Next location is on the map: True
# Obstacle at this location? False
# The guard is at (69, 56)
# Next guard location is (69, 57)
# Next location is on the map: True
# Obstacle at this location? False
# The guard is at (69, 57)
# Next guard location is (69, 58)
# Next location is on the map: True
# Obstacle at this location? False
# The guard is at (69, 58)
# Next guard location is (69, 59)
# Next location is on the map: True
# Obstacle at this location? False
# The guard is at (69, 59)
# Next guard location is (69, 60)
# Next location is on the map: True
# Obstacle at this location? False
# The guard is at (69, 60)
# Next guard location is (69, 61)
# Next location is on the map: True
# Obstacle at this location? False
# The guard is at (69, 61)
# Next guard location is (69, 62)
# Next location is on the map: True
# Obstacle at this location? False
# The guard is at (69, 62)
# Next guard location is (69, 63)
# Next location is on the map: True
# Obstacle at this location? False
# The guard is at (69, 63)
# Next guard location is (69, 64)
# Next location is on the map: True
# Obstacle at this location? False
# The guard is at (69, 64)
# Next guard location is (69, 65)
# Next location is on the map: True
# Obstacle at this location? False
# The guard is at (69, 65)
# Next guard location is (69, 66)
# Next location is on the map: True
# Obstacle at this location? False
# The guard is at (69, 66)
# Next guard location is (69, 67)
# Next location is on the map: True
# Obstacle at this location? False
# The guard is at (69, 67)
# Next guard location is (69, 68)
# Next location is on the map: True
# Obstacle at this location? False
# The guard is at (69, 68)
# Next guard location is (69, 69)
# Next location is on the map: True
# Obstacle at this location? False
# The guard is at (69, 69)
# Next guard location is (69, 70)
# Next location is on the map: True
# Obstacle at this location? False
# The guard is at (69, 70)
# Next guard location is (69, 71)
# Next location is on the map: True
# Obstacle at this location? False
# The guard is at (69, 71)
# Next guard location is (69, 72)
# Next location is on the map: True
# Obstacle at this location? True
# The guard is at (69, 71)
# Next guard location is (68, 71)
# Next location is on the map: True
# Obstacle at this location? False
# The guard is at (68, 71)
# Next guard location is (67, 71)
# Next location is on the map: True
# Obstacle at this location? False
# The guard is at (67, 71)
# Next guard location is (66, 71)
# Next location is on the map: True
# Obstacle at this location? False
# The guard is at (66, 71)
# Next guard location is (65, 71)
# Next location is on the map: True
# Obstacle at this location? False
# ...
# Next location is on the map: True
# Obstacle at this location? False
# The guard is at (121, 70)
# Next guard location is (121, 69)
# Next location is on the map: True
# Obstacle at this location? False
# The guard is at (121, 69)
# Next guard location is (121, 68)
# Next location is on the map: True
# Obstacle at this location? False
# The guard is at (121, 68)
# Next guard location is (121, 67)
# Next location is on the map: True
# Obstacle at this location? False
# The guard is at (121, 67)
# Next guard location is (121, 66)
# Next location is on the map: True
# Obstacle at this location? False
# The guard is at (121, 66)
# Next guard location is (121, 65)
# Next location is on the map: True
# Obstacle at this location? False
# The guard is at (121, 65)
# Next guard location is (121, 64)
# Next location is on the map: True
# Obstacle at this location? False
# The guard is at (121, 64)
# Next guard location is (121, 63)
# Next location is on the map: True
# Obstacle at this location? False
# The guard is at (121, 63)
# Next guard location is (121, 62)
# Next location is on the map: True
# Obstacle at this location? False
# The guard is at (121, 62)
# Next guard location is (121, 61)
# Next location is on the map: True
# Obstacle at this location? False
# The guard is at (121, 61)
# Next guard location is (121, 60)
# Next location is on the map: True
# Obstacle at this location? False
# The guard is at (121, 60)
# Next guard location is (121, 59)
# Next location is on the map: True
# Obstacle at this location? False
# The guard is at (121, 59)
# Next guard location is (121, 58)
# Next location is on the map: True
# Obstacle at this location? False
# The guard is at (121, 58)
# Next guard location is (121, 57)
# Next location is on the map: True
# Obstacle at this location? False
# The guard is at (121, 57)
# Next guard location is (121, 56)
# Next location is on the map: True
# Obstacle at this location? False
# The guard is at (121, 56)
# Next guard location is (121, 55)
# Next location is on the map: True
# Obstacle at this location? False
# The guard is at (121, 55)
# Next guard location is (121, 54)
# Next location is on the map: True
# Obstacle at this location? False
# The guard is at (121, 54)
# Next guard location is (121, 53)
# Next location is on the map: True
# Obstacle at this location? False
# The guard is at (121, 53)
# Next guard location is (121, 52)
# Next location is on the map: True
# Obstacle at this location? False
# The guard is at (121, 52)
# Next guard location is (121, 51)
# Next location is on the map: True
# Obstacle at this location? False
# The guard is at (121, 51)
# Next guard location is (121, 50)
# Next location is on the map: True
# Obstacle at this location? False
# The guard is at (121, 50)
# Next guard location is (121, 49)
# Next location is on the map: True
# Obstacle at this location? False
# The guard is at (121, 49)
# Next guard location is (121, 48)
# Next location is on the map: True
# Obstacle at this location? False
# The guard is at (121, 48)
# Next guard location is (121, 47)
# Next location is on the map: True
# Obstacle at this location? False
# The guard is at (121, 47)
# Next guard location is (121, 46)
# Next location is on the map: True
# Obstacle at this location? False
# The guard is at (121, 46)
# Next guard location is (121, 45)
# Next location is on the map: True
# Obstacle at this location? False
# The guard is at (121, 45)
# Next guard location is (121, 44)
# Next location is on the map: True
# Obstacle at this location? False
# The guard is at (121, 44)
# Next guard location is (121, 43)
# Next location is on the map: True
# Obstacle at this location? False
# The guard is at (121, 43)
# Next guard location is (121, 42)
# Next location is on the map: True
# Obstacle at this location? False
# The guard is at (121, 42)
# Next guard location is (121, 41)
# Next location is on the map: True
# Obstacle at this location? False
# The guard is at (121, 41)
# Next guard location is (121, 40)
# Next location is on the map: True
# Obstacle at this location? False
# The guard is at (121, 40)
# Next guard location is (121, 39)
# Next location is on the map: True
# Obstacle at this location? False
# The guard is at (121, 39)
# Next guard location is (121, 38)
# Next location is on the map: True
# Obstacle at this location? True
# The guard is at (121, 39)
# Next guard location is (122, 39)
# Next location is on the map: True
# Obstacle at this location? False
# The guard is at (122, 39)
# Next guard location is (123, 39)
# Next location is on the map: True
# Obstacle at this location? False
# The guard is at (123, 39)
# Next guard location is (124, 39)
# Next location is on the map: True
# Obstacle at this location? False
# The guard is at (124, 39)
# Next guard location is (125, 39)
# Next location is on the map: True
# Obstacle at this location? False
# The guard is at (125, 39)
# Next guard location is (126, 39)
# Next location is on the map: True
# Obstacle at this location? False
# The guard is at (126, 39)
# Next guard location is (127, 39)
# Next location is on the map: True
# Obstacle at this location? True
# The guard is at (126, 39)
# Next guard location is (126, 40)
# Next location is on the map: True
# Obstacle at this location? False
# The guard is at (126, 40)
# Next guard location is (126, 41)
# Next location is on the map: True
# Obstacle at this location? False
# The guard is at (126, 41)
# Next guard location is (126, 42)
# Next location is on the map: True
# Obstacle at this location? False
# The guard is at (126, 42)
# Next guard location is (126, 43)
# Next location is on the map: True
# Obstacle at this location? False
# The guard is at (126, 43)
# Next guard location is (126, 44)
# Next location is on the map: True
# Obstacle at this location? False
# The guard is at (126, 44)
# Next guard location is (126, 45)
# Next location is on the map: True
# Obstacle at this location? False
# The guard is at (126, 45)
# Next guard location is (126, 46)
# Next location is on the map: True
# Obstacle at this location? False
# The guard is at (126, 46)
# Next guard location is (126, 47)
# Next location is on the map: True
# Obstacle at this location? False
# The guard is at (126, 47)
# Next guard location is (126, 48)
# Next location is on the map: True
# Obstacle at this location? False
# The guard is at (126, 48)
# Next guard location is (126, 49)
# Next location is on the map: True
# Obstacle at this location? False
# The guard is at (126, 49)
# Next guard location is (126, 50)
# Next location is on the map: True
# Obstacle at this location? False
# The guard is at (126, 50)
# Next guard location is (126, 51)
# Next location is on the map: True
# Obstacle at this location? False
# The guard is at (126, 51)
# Next guard location is (126, 52)
# Next location is on the map: True
# Obstacle at this location? False
# The guard is at (126, 52)
# Next guard location is (126, 53)
# Next location is on the map: True
# Obstacle at this location? False
# The guard is at (126, 53)
# Next guard location is (126, 54)
# Next location is on the map: True
# Obstacle at this location? False
# The guard is at (126, 54)
# Next guard location is (126, 55)
# Next location is on the map: True
# Obstacle at this location? False
# The guard is at (126, 55)
# Next guard location is (126, 56)
# Next location is on the map: True
# Obstacle at this location? False
# The guard is at (126, 56)
# Next guard location is (126, 57)
# Next location is on the map: True
# Obstacle at this location? False
# The guard is at (126, 57)
# Next guard location is (126, 58)
# Next location is on the map: True
# Obstacle at this location? False
# The guard is at (126, 58)
# Next guard location is (126, 59)
# Next location is on the map: True
# Obstacle at this location? False
# The guard is at (126, 59)
# Next guard location is (126, 60)
# Next location is on the map: True
# Obstacle at this location? False
# The guard is at (126, 60)
# Next guard location is (126, 61)
# Next location is on the map: True
# Obstacle at this location? False
# The guard is at (126, 61)
# Next guard location is (126, 62)
# Next location is on the map: True
# Obstacle at this location? False
# The guard is at (126, 62)
# Next guard location is (126, 63)
# Next location is on the map: True
# Obstacle at this location? False
# The guard is at (126, 63)
# Next guard location is (126, 64)
# Next location is on the map: True
# Obstacle at this location? False
# The guard is at (126, 64)
# Next guard location is (126, 65)
# Next location is on the map: True
# Obstacle at this location? False
# The guard is at (126, 65)
# Next guard location is (126, 66)
# Next location is on the map: True
# Obstacle at this location? False
# The guard is at (126, 66)
# Next guard location is (126, 67)
# Next location is on the map: True
# Obstacle at this location? False
# The guard is at (126, 67)
# Next guard location is (126, 68)
# Next location is on the map: True
# Obstacle at this location? False
# The guard is at (126, 68)
# Next guard location is (126, 69)
# Next location is on the map: True
# Obstacle at this location? False
# The guard is at (126, 69)
# Next guard location is (126, 70)
# Next location is on the map: True
# Obstacle at this location? False
# The guard is at (126, 70)
# Next guard location is (126, 71)
# Next location is on the map: True
# Obstacle at this location? False
# The guard is at (126, 71)
# Next guard location is (126, 72)
# Next location is on the map: True
# Obstacle at this location? False
# The guard is at (126, 72)
# Next guard location is (126, 73)
# Next location is on the map: True
# Obstacle at this location? False
# The guard is at (126, 73)
# Next guard location is (126, 74)
# Next location is on the map: True
# Obstacle at this location? False
# The guard is at (126, 74)
# Next guard location is (126, 75)
# Next location is on the map: True
# Obstacle at this location? False
# The guard is at (126, 75)
# Next guard location is (126, 76)
# Next location is on the map: True
# Obstacle at this location? False
# The guard is at (126, 76)
# Next guard location is (126, 77)
# Next location is on the map: True
# Obstacle at this location? False
# The guard is at (126, 77)
# Next guard location is (126, 78)
# Next location is on the map: True
# Obstacle at this location? False
# The guard is at (126, 78)
# Next guard location is (126, 79)
# Next location is on the map: True
# Obstacle at this location? False
# The guard is at (126, 79)
# Next guard location is (126, 80)
# Next location is on the map: True
# Obstacle at this location? False
# The guard is at (126, 80)
# Next guard location is (126, 81)
# Next location is on the map: True
# Obstacle at this location? False
# The guard is at (126, 81)
# Next guard location is (126, 82)
# Next location is on the map: True
# Obstacle at this location? False
# The guard is at (126, 82)
# Next guard location is (126, 83)
# Next location is on the map: True
# Obstacle at this location? False
# The guard is at (126, 83)
# Next guard location is (126, 84)
# Next location is on the map: True
# Obstacle at this location? False
# The guard is at (126, 84)
# Next guard location is (126, 85)
# Next location is on the map: True
# Obstacle at this location? False
# The guard is at (126, 85)
# Next guard location is (126, 86)
# Next location is on the map: True
# Obstacle at this location? False
# The guard is at (126, 86)
# Next guard location is (126, 87)
# Next location is on the map: True
# Obstacle at this location? False
# The guard is at (126, 87)
# Next guard location is (126, 88)
# Next location is on the map: True
# Obstacle at this location? True
# The guard is at (126, 87)
# Next guard location is (125, 87)
# Next location is on the map: True
# Obstacle at this location? False
# The guard is at (125, 87)
# Next guard location is (124, 87)
# Next location is on the map: True
# Obstacle at this location? False
# The guard is at (124, 87)
# Next guard location is (123, 87)
# Next location is on the map: True
# Obstacle at this location? False
# The guard is at (123, 87)
# Next guard location is (122, 87)
# Next location is on the map: True
# Obstacle at this location? False
# The guard is at (122, 87)
# Next guard location is (121, 87)
# Next location is on the map: True
# Obstacle at this location? False
# The guard is at (121, 87)
# Next guard location is (120, 87)
# Next location is on the map: True
# Obstacle at this location? False
# The guard is at (120, 87)
# Next guard location is (119, 87)
# Next location is on the map: True
# Obstacle at this location? False
# The guard is at (119, 87)
# Next guard location is (118, 87)
# Next location is on the map: True
# Obstacle at this location? False
# The guard is at (118, 87)
# Next guard location is (117, 87)
# Next location is on the map: True
# Obstacle at this location? True
# The guard is at (118, 87)
# Next guard location is (118, 86)
# Next location is on the map: True
# Obstacle at this location? False
# The guard is at (118, 86)
# Next guard location is (118, 85)
# Next location is on the map: True
# Obstacle at this location? False
# The guard is at (118, 85)
# Next guard location is (118, 84)
# Next location is on the map: True
# Obstacle at this location? False
# The guard is at (118, 84)
# Next guard location is (118, 83)
# Next location is on the map: True
# Obstacle at this location? False
# The guard is at (118, 83)
# Next guard location is (118, 82)
# Next location is on the map: True
# Obstacle at this location? False
# The guard is at (118, 82)
# Next guard location is (118, 81)
# Next location is on the map: True
# Obstacle at this location? False
# The guard is at (118, 81)
# Next guard location is (118, 80)
# Next location is on the map: True
# Obstacle at this location? False
# The guard is at (118, 80)
# Next guard location is (118, 79)
# Next location is on the map: True
# Obstacle at this location? False
# The guard is at (118, 79)
# Next guard location is (118, 78)
# Next location is on the map: True
# Obstacle at this location? False
# The guard is at (118, 78)
# Next guard location is (118, 77)
# Next location is on the map: True
# Obstacle at this location? False
# The guard is at (118, 77)
# Next guard location is (118, 76)
# Next location is on the map: True
# Obstacle at this location? False
# The guard is at (118, 76)
# Next guard location is (118, 75)
# Next location is on the map: True
# Obstacle at this location? False
# The guard is at (118, 75)
# Next guard location is (118, 74)
# Next location is on the map: True
# Obstacle at this location? False
# The guard is at (118, 74)
# Next guard location is (118, 73)
# Next location is on the map: True
# Obstacle at this location? False
# The guard is at (118, 73)
# Next guard location is (118, 72)
# Next location is on the map: True
# Obstacle at this location? False
# The guard is at (118, 72)
# Next guard location is (118, 71)
# Next location is on the map: True
# Obstacle at this location? False
# The guard is at (118, 71)
# Next guard location is (118, 70)
# Next location is on the map: True
# Obstacle at this location? False
# The guard is at (118, 70)
# Next guard location is (118, 69)
# Next location is on the map: True
# Obstacle at this location? False
# The guard is at (118, 69)
# Next guard location is (118, 68)
# Next location is on the map: True
# Obstacle at this location? True
# The guard is at (118, 69)
# Next guard location is (119, 69)
# Next location is on the map: True
# Obstacle at this location? False
# The guard is at (119, 69)
# Next guard location is (120, 69)
# Next location is on the map: True
# Obstacle at this location? False
# The guard is at (120, 69)
# Next guard location is (121, 69)
# Next location is on the map: True
# Obstacle at this location? False
# The guard is at (121, 69)
# Next guard location is (122, 69)
# Next location is on the map: True
# Obstacle at this location? False
# The guard is at (122, 69)
# Next guard location is (123, 69)
# Next location is on the map: True
# Obstacle at this location? False
# The guard is at (123, 69)
# Next guard location is (124, 69)
# Next location is on the map: True
# Obstacle at this location? False
# The guard is at (124, 69)
# Next guard location is (125, 69)
# Next location is on the map: True
# Obstacle at this location? False
# The guard is at (125, 69)
# Next guard location is (126, 69)
# Next location is on the map: True
# Obstacle at this location? False
# The guard is at (126, 69)
# Next guard location is (127, 69)
# Next location is on the map: True
# Obstacle at this location? False
# The guard is at (127, 69)
# Next guard location is (128, 69)
# Next location is on the map: True
# Obstacle at this location? False
# The guard is at (128, 69)
# Next guard location is (129, 69)
# Next location is on the map: True
# Obstacle at this location? False
# The guard has been to 5269 spots

# %%
#for loop to iterate through all the positions until guard leaves the map


s = s[:index] + newstring + s[index + 1:]
